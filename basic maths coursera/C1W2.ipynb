# %%
import numpy as np

# %%
import w2_unittest

# %%
A = np.array([     
        [2,-1,1,1],
        [1,2,-1,-1],
        [-1,2,2,2],
        [1,-1,2,1]    
    ], dtype=np.dtype(float)) 
b = np.array([6,3,14,8], dtype=np.dtype(float))
print(A)
print(b)
# Out:
# [[ 2. -1.  1.  1.]
#  [ 1.  2. -1. -1.]
#  [-1.  2.  2.  2.]
#  [ 1. -1.  2.  1.]]
# [ 6.  3. 14.  8.]

# %%
w2_unittest.test_matrix(A, b)
# Out:
#  All tests passed
